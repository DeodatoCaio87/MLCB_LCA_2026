# %%
# ==============================================================================
# GERAÇÃO DO DATASET - MÓVEIS RESIDENCIAIS
# ==============================================================================

import pandas as pd
import random


# ==============================================================================
# CONFIGURAÇÕES
# ==============================================================================

random.seed(42)


# ==============================================================================
# FRASES PARA CADA INTENÇÃO
# ==============================================================================

dados = []


# ------------------------------------------------------------------------------
# INTENÇÃO: VENDAS
# ------------------------------------------------------------------------------

vendas = [
    "Quero comprar um sofá",
    "Gostaria de comprar uma mesa",
    "Quero saber o preço de um guarda roupa",
    "Vocês vendem camas?",
    "Quero comprar uma cadeira",
    "Gostaria de adquirir um armário",
    "Qual o preço desse sofá?",
    "Quais móveis estão disponíveis?",
    "Quero comprar móveis para minha casa",
    "Gostaria de ver os produtos disponíveis",
    "Vocês têm mesas de jantar?",
    "Quero comprar um rack",
    "Preciso de um sofá novo",
    "Quero saber o valor da estante",
    "Vocês vendem cômodas?",
    "Gostaria de comprar uma escrivaninha",
    "Quero consultar os preços dos móveis",
    "Quais sofás vocês possuem?",
    "Quero comprar um painel para TV",
    "Gostaria de saber os produtos disponíveis"
]


# ------------------------------------------------------------------------------
# INTENÇÃO: SUPORTE
# ------------------------------------------------------------------------------

suporte = [
    "Preciso de ajuda com meu móvel",
    "Como faço para montar o sofá?",
    "Preciso de suporte para montar minha mesa",
    "Meu móvel apresentou um problema",
    "Como posso montar meu armário?",
    "Preciso de ajuda com a montagem",
    "O manual de montagem não veio",
    "Não consigo montar minha cadeira",
    "Preciso de assistência técnica",
    "Meu móvel está com defeito",
    "Como faço para solicitar suporte?",
    "Preciso de ajuda com meu pedido",
    "Tenho dúvidas sobre a montagem",
    "A montagem do móvel está difícil",
    "Preciso de assistência com meu produto",
    "Meu armário apresentou um problema",
    "Não estou conseguindo montar o produto",
    "Gostaria de falar com o suporte",
    "Preciso de ajuda técnica",
    "Como consigo assistência para meu móvel"
]


# ------------------------------------------------------------------------------
# INTENÇÃO: TROCAS E DEVOLUÇÕES
# ------------------------------------------------------------------------------

trocas_devolucoes = [
    "Quero trocar meu sofá",
    "Como faço para devolver um móvel?",
    "Quero devolver minha compra",
    "Posso trocar uma cadeira?",
    "Gostaria de solicitar uma troca",
    "Como funciona a devolução?",
    "Recebi o móvel e quero devolver",
    "Quero trocar o produto que comprei",
    "Posso devolver meu pedido?",
    "Quero realizar uma troca",
    "Como faço para trocar um produto?",
    "Gostaria de devolver meu móvel",
    "Preciso trocar minha mesa",
    "Quero cancelar e devolver o produto",
    "Qual o prazo para devolução?",
    "Como funciona a política de troca?",
    "Recebi o produto errado e quero trocar",
    "Quero devolver um produto comprado",
    "Preciso solicitar uma devolução",
    "Gostaria de saber como realizar uma troca"
]


# ------------------------------------------------------------------------------
# INTENÇÃO: RECLAMAÇÕES
# ------------------------------------------------------------------------------

reclamacoes = [
    "Estou insatisfeito com minha compra",
    "Quero fazer uma reclamação",
    "Meu pedido veio com problema",
    "Estou muito insatisfeito com o atendimento",
    "Quero reclamar do produto",
    "O móvel chegou danificado",
    "Estou decepcionado com a compra",
    "O produto veio errado",
    "Tenho uma reclamação sobre meu pedido",
    "O atendimento foi muito ruim",
    "Estou insatisfeito com o produto",
    "Quero registrar uma reclamação",
    "Meu móvel chegou quebrado",
    "Estou tendo problemas com minha compra",
    "Quero reclamar sobre o atendimento",
    "O produto não veio como esperado",
    "Minha compra apresentou problemas",
    "Estou muito insatisfeito",
    "Quero registrar uma queixa",
    "Tenho um problema grave com meu pedido"
]


# ------------------------------------------------------------------------------
# INTENÇÃO: LOGÍSTICA E ENTREGAS
# ------------------------------------------------------------------------------

logistica_entregas = [
    "Onde está meu pedido?",
    "Quero acompanhar minha entrega",
    "Qual o prazo de entrega?",
    "Quando meu pedido vai chegar?",
    "Meu pedido ainda não chegou",
    "Como rastrear minha compra?",
    "Quero saber onde está minha entrega",
    "Qual a previsão de entrega?",
    "Minha entrega está atrasada",
    "Quando vocês vão entregar meu móvel?",
    "Posso acompanhar o pedido?",
    "Gostaria de rastrear minha compra",
    "Meu pedido está atrasado",
    "Qual a data da entrega?",
    "Quero consultar o status da entrega",
    "Minha compra ainda não foi entregue",
    "Como faço para rastrear o pedido?",
    "Preciso saber quando o móvel chegará",
    "Onde posso acompanhar minha entrega?",
    "Gostaria de informações sobre a entrega"
]


# ==============================================================================
# MONTAR DATASET
# ==============================================================================

for frase in vendas:

    dados.append({
        "texto": frase,
        "intencao": "vendas"
    })


for frase in suporte:

    dados.append({
        "texto": frase,
        "intencao": "suporte"
    })


for frase in trocas_devolucoes:

    dados.append({
        "texto": frase,
        "intencao": "trocas_devolucoes"
    })


for frase in reclamacoes:

    dados.append({
        "texto": frase,
        "intencao": "reclamacoes"
    })


for frase in logistica_entregas:

    dados.append({
        "texto": frase,
        "intencao": "logistica_entregas"
    })


# ==============================================================================
# CRIAR DATAFRAME
# ==============================================================================

df = pd.DataFrame(
    dados
)


# ==============================================================================
# EMBARALHAR OS DADOS
# ==============================================================================

df = df.sample(
    frac=1,
    random_state=42
).reset_index(
    drop=True
)


# ==============================================================================
# SALVAR CSV
# ==============================================================================

df.to_csv(
    'dataset_moveis_100.csv',
    index=False,
    encoding='utf-8'
)


# ==============================================================================
# VERIFICAÇÃO
# ==============================================================================

print(
    "Dataset criado com sucesso!"
)

print(
    f"Total de registros: {len(df)}"
)

print(
    "\nQuantidade por intenção:"
)

print(
    df['intencao'].value_counts()
)

print(
    "\nPrimeiras linhas do dataset:"
)

print(
    df.head()
)
# Out:
# Dataset criado com sucesso!
# Total de registros: 100
#
# Quantidade por intenção:
# intencao
# logistica_entregas    20
# trocas_devolucoes     20
# reclamacoes           20
# suporte               20
# vendas                20
# Name: count, dtype: int64
#
# Primeiras linhas do dataset:
#                                  texto            intencao
# 0        Quando meu pedido vai chegar?  logistica_entregas
# 1  Quero cancelar e devolver o produto   trocas_devolucoes
# 2     Estou insatisfeito com o produto         reclamacoes
# 3           Como funciona a devolução?   trocas_devolucoes
# 4      Gostaria de solicitar uma troca   trocas_devolucoes
